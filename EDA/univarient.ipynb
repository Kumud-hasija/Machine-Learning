# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("../Datasets/train.csv")

# %% [markdown]
# # Understanding data

# %%
df.shape
# Out:
# (891, 12)

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 160          161         0       3
# 854          855         0       2
# 470          471         0       3
# 64            65         0       1
# 184          185         1       3
#
#                                               Name     Sex   Age  SibSp  \
# 160                       Cribb, Mr. John Hatfield    male  44.0      0
# 854  Carter, Mrs. Ernest Courtenay (Lilian Hughes)  female  44.0      1
# 470                              Keefe, Mr. Arthur    male   NaN      0
# 64                           Stewart, Mr. Albert A    male   NaN      0
# 184            Kink-Heilmann, Miss. Luise Gretchen  female   4.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 160      1    371362  16.1000   NaN        S
# 854      0    244252  26.0000   NaN        S
# 470      0    323592   7.2500   NaN        S
# 64       0  PC 17605  27.7208   NaN        C
# 184      2    315153  22.0250   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 1. categorical data

# %% [markdown]
# # a. countplot

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# sns.countplot(df['Survived'])
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(df['Pclass'])
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# b. Pie chart

# %%
df['Survived'].value_counts().plot(kind='pie' ,autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 2. Numerical data

# %% [markdown]
# a. histogram

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Age'],bins=10)
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # b. displot

# %%
sns.displot(df['Age'])

# %% [markdown]
# c. boxplot
# used to identify outliers
# ![image.png](attachment:image.png)

# %%
plt.boxplot(df['Fare'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a8e0c10ce0>,
#   <matplotlib.lines.Line2D at 0x2a8e0c10e60>],
#  'caps': [<matplotlib.lines.Line2D at 0x2a8e0c11100>,
#   <matplotlib.lines.Line2D at 0x2a8e0c11430>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2a8e0c10a40>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a8e0c11730>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a8e0c119d0>],
#  'means': []}

# %%
print(df['Age'].min())
print(df['Age'].max())
print(df['Age'].skew())
# Out:
# 0.42
# 80.0
# 0.38910778230082704
