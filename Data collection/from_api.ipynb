# %% [markdown]
# API - application programming interface

# %%
import pandas as pd
import requests

# %%
response= requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1")

# %%
df = pd.DataFrame(response.json()['results'])
df
# Out:
#     adult                     backdrop_path         genre_ids       id  \
# 0   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]      278
# 1   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]      238
# 2   False  /ixKQ55OL3S4Lm0wuKU0s09cVGpX.jpg      [28, 12, 53]  1356039
# 3   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]      240
# 4   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]      424
# 5   False  /bxgTSUenZDHNFerQ1whRKplrMKF.jpg              [18]      389
# 6   False  /6oaL4DP75yABrd5EbC4H2zq5ghc.jpg   [16, 10751, 14]      129
# 7   False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg   [35, 18, 10749]    19404
# 8   False  /oOv2oUXcAaNXakRqUPxYq5lJURz.jpg  [18, 28, 80, 53]      155
# 9   False  /vxJ08SvwomfKbpboCWynC3uqUg4.jpg      [14, 18, 80]      497
# 10  False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg      [35, 53, 18]   496243
# 11  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          [53, 80]      680
# 12  False  /8x9iKH8kWA0zdkgNdpAew7OstYe.jpg   [16, 10749, 18]   372058
# 13  False  /2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg      [12, 14, 28]      122
# 14  False  /mzfx54nfDPTUXZOG48u4LaEheDy.jpg   [35, 18, 10749]       13
# 15  False  /x4biAVdPVCghBlsVIzB6NmbghIz.jpg              [37]      429
# 16  False  /sJNNMCc6B7KZIY3LH3JMYJJNH5j.jpg          [28, 18]      346
# 17  False  /7TF4p86ZafnxFuNqWdhpHXFO244.jpg          [18, 80]      769
# 18  False   /8sNiAPPYU14PUepFNeSNGUTiHW.jpg     [12, 18, 878]   157336
# 19  False  /tDFvXn4tane9lUvFAFAUkMylwSr.jpg   [16, 18, 10752]    12477
#
#    original_language                                 original_title  \
# 0                 en                       The Shawshank Redemption
# 1                 en                                  The Godfather
# 2                 es                                   Contraataque
# 3                 en                          The Godfather Part II
# 4                 en                               Schindler's List
# 5                 en                                   12 Angry Men
# 6                 ja                                       千と千尋の神隠し
# 7                 hi                   दिलवाले दुल्हनिया ले जायेंगे
# 8                 en                                The Dark Knight
# 9                 en                                 The Green Mile
# 10                ko                                            기생충
# 11                en                                   Pulp Fiction
# 12                ja                                          君の名は。
# 13                en  The Lord of the Rings: The Return of the King
# 14                en                                   Forrest Gump
# 15                it                Il buono, il brutto, il cattivo
# 16                ja                                           七人の侍
# 17                en                                     GoodFellas
# 18                en                                   Interstellar
# 19                ja                                          火垂るの墓
#
#                                              overview  popularity  \
# 0   Imprisoned in the 1940s for the double murder ...      48.422
# 1   Spanning the years 1945 to 1955, a chronicle o...      48.586
# 2   When a hostage rescue mission creates a new en...     110.879
# 3   In the continuing saga of the Corleone crime f...      25.980
# 4   The true story of how businessman Oskar Schind...      25.518
# 5   The defense and the prosecution have rested an...      19.003
# 6   A young girl, Chihiro, becomes trapped in a st...      24.783
# 7   Raj is a rich, carefree, happy-go-lucky second...      13.573
# 8   Batman raises the stakes in his war on crime. ...      44.406
# 9   A supernatural tale set on death row in a Sout...      24.301
# 10  All unemployed, Ki-taek's family takes peculia...      37.722
# 11  A burger-loving hit man, his philosophical par...      30.839
# 12  High schoolers Mitsuha and Taki are complete s...      25.460
# 13  As armies mass for a final battle that will de...      41.484
# 14  A man with a low IQ has accomplished great thi...      27.685
# 15  While the Civil War rages on between the Union...      19.521
# 16  A samurai answers a village's request for prot...      10.651
# 17  The true story of Henry Hill, a half-Irish, ha...      20.107
# 18  The adventures of a group of explorers who mak...      60.185
# 19  In the final months of World War II, 14-year-o...       0.023
#
#                          poster_path release_date  \
# 0   /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23
# 1   /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14
# 2   /lI2uFlSEkwXKljqiry7coaJ6wIS.jpg   2025-02-27
# 3   /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20
# 4   /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15
# 5   /ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg   1957-04-10
# 6   /39wmItIWsg5sZMyRUHLkWBcuVCM.jpg   2001-07-20
# 7   /lfRkUr7DYdHldAqi3PwdQGBRBPM.jpg   1995-10-20
# 8   /qJ2tW6WMUDux911r6m7haRef0WH.jpg   2008-07-16
# 9   /8VG8fDNiy50H4FedGwdSVUPoaJe.jpg   1999-12-10
# 10  /7IiTTgloJzvGI1TAYymCfbfl3vT.jpg   2019-05-30
# 11  /jYqKxBbAUdfKq3BfHKivJytFiPL.jpg   1994-09-10
# 12  /q719jXXEzOoYaps6babgKnONONX.jpg   2016-08-26
# 13  /rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg   2003-12-17
# 14  /arw2vcBveWOVZr6pxd9XTd1TdQa.jpg   1994-06-23
# 15  /bX2xnavhMYjWDoZp1VM6VnU1xwe.jpg   1966-12-22
# 16  /8OKmBV5BUFzmozIC3pPWKHy17kx.jpg   1954-04-26
# 17  /aKuFiU82s5ISJpGZp7YkIr3kCUd.jpg   1990-09-12
# 18  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg   2014-11-05
# 19  /k9tv1rXZbOhH7eiCk378x61kNQ1.jpg   1988-04-16
#
#                                             title  video  vote_average  \
# 0                        The Shawshank Redemption  False         8.708
# 1                                   The Godfather  False         8.689
# 2                                   Counterattack  False         8.619
# 3                           The Godfather Part II  False         8.570
# 4                                Schindler's List  False         8.567
# 5                                    12 Angry Men  False         8.548
# 6                                   Spirited Away  False         8.500
# 7                     Dilwale Dulhania Le Jayenge  False         8.520
# 8                                 The Dark Knight  False         8.519
# 9                                  The Green Mile  False         8.505
# 10                                       Parasite  False         8.500
# 11                                   Pulp Fiction  False         8.489
# 12                                     Your Name.  False         8.487
# 13  The Lord of the Rings: The Return of the King  False         8.481
# 14                                   Forrest Gump  False         8.468
# 15                 The Good, the Bad and the Ugly  False         8.462
# 16                                  Seven Samurai  False         8.500
# 17                                     GoodFellas  False         8.500
# 18                                   Interstellar  False         8.452
# 19                         Grave of the Fireflies  False         8.452
#
#     vote_count
# 0        27845
# 1        21128
# 2          333
# 3        12756
# 4        16203
# 5         8939
# 6        16883
# 7         4466
# 8        33511
# 9        17875
# 10       18759
# 11       28405
# 12       11631
# 13       24768
# 14       27928
# 15        8841
# 16        3814
# 17       13162
# 18       36664
# 19        5759

# %%
data = pd.DataFrame()

for i in range(1,10):
    response= requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}".format(i))
    temp = pd.DataFrame(response.json()['results'])
    data = pd.concat([data,temp] , ignore_index=True)

data
# Out:
#      adult                     backdrop_path        genre_ids       id  \
# 0    False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         [18, 80]      278
# 1    False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg         [18, 80]      238
# 2    False  /ixKQ55OL3S4Lm0wuKU0s09cVGpX.jpg     [28, 12, 53]  1356039
# 3    False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg         [18, 80]      240
# 4    False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg  [18, 36, 10752]      424
# ..     ...                               ...              ...      ...
# 175  False   /BBVAUchYvkmPThVIqipgAfabfl.jpg             [18]      614
# 176  False  /zvOJawrnmgK0sL293mOXOdLvTXQ.jpg      [10749, 18]   398818
# 177  False  /vINgGecnz95iDL6fjQMARDsocgG.jpg    [28, 53, 878]      280
# 178  False  /jqFjgNnxpXIXWuPsyfqmcLXRo9p.jpg         [80, 53]      500
# 179  False  /h3weAFgg06GqchI2xDfufBgSFTj.jpg             [18]   600354
#
#     original_language              original_title  \
# 0                  en    The Shawshank Redemption
# 1                  en               The Godfather
# 2                  es                Contraataque
# 3                  en       The Godfather Part II
# 4                  en            Schindler's List
# ..                ...                         ...
# 175                sv             Smultronstället
# 176                en        Call Me by Your Name
# 177                en  Terminator 2: Judgment Day
# 178                en              Reservoir Dogs
# 179                en                  The Father
#
#                                               overview  popularity  \
# 0    Imprisoned in the 1940s for the double murder ...      48.422
# 1    Spanning the years 1945 to 1955, a chronicle o...      48.586
# 2    When a hostage rescue mission creates a new en...     110.879
# 3    In the continuing saga of the Corleone crime f...      25.980
# 4    The true story of how businessman Oskar Schind...      25.518
# ..                                                 ...         ...
# 175  Crotchety retired doctor Isak Borg travels fro...       3.823
# 176  In 1980s Italy, a relationship begins between ...      21.695
# 177  Set ten years after the events of the original...      21.026
# 178  A botched robbery indicates a police informant...      12.662
# 179  A man refuses all assistance from his daughter...       7.037
#
#                           poster_path release_date  \
# 0    /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23
# 1    /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14
# 2    /lI2uFlSEkwXKljqiry7coaJ6wIS.jpg   2025-02-27
# 3    /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20
# 4    /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15
# ..                                ...          ...
# 175  /iyTD2QnySNMPUPE3IedZQipSWfz.jpg   1957-08-28
# 176  /gXiE0WveDnT0n5J4sW9TMxXF4oT.jpg   2017-07-28
# 177  /5M0j0B18abtBI5gi2RhfjjurTqb.jpg   1991-07-03
# 178  /xi8Iu6qyTfyZVDVy60raIOYJJmk.jpg   1992-09-02
# 179  /xxHNaCMycynHMKdEZHHQCzaPbZl.jpg   2020-12-23
#
#                           title  video  vote_average  vote_count
# 0      The Shawshank Redemption  False         8.708       27845
# 1                 The Godfather  False         8.689       21128
# 2                 Counterattack  False         8.619         333
# 3         The Godfather Part II  False         8.570       12756
# 4              Schindler's List  False         8.567       16203
# ..                          ...    ...           ...         ...
# 175           Wild Strawberries  False         8.123        1662
# 176        Call Me by Your Name  False         8.100       12220
# 177  Terminator 2: Judgment Day  False         8.121       13136
# 178              Reservoir Dogs  False         8.120       14486
# 179                  The Father  False         8.117        3264
#
# [180 rows x 14 columns]

# %%
df.to_csv('movie.csv')
